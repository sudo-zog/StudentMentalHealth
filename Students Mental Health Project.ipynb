# %% [markdown]
# # Student Mental Health

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Dataset

# %%
df= pd.read_csv("Student Mental health.csv", index_col= [0])

# %% [markdown]
# ## Checking Dataset/cleaning some data

# %%
df.head(6)
# Out:
#                Choose your gender   Age What is your course?  \
# Timestamp
# 8/7/2020 12:02             Female  18.0          Engineering
# 8/7/2020 12:04               Male  21.0    Islamic education
# 8/7/2020 12:05               Male  19.0                  BIT
# 8/7/2020 12:06             Female  22.0                 Laws
# 8/7/2020 12:13               Male  23.0         Mathemathics
# 8/7/2020 12:31               Male  19.0          Engineering
#
#                Your current year of Study What is your CGPA? Marital status  \
# Timestamp
# 8/7/2020 12:02                     year 1        3.00 - 3.49             No
# 8/7/2020 12:04                     year 2        3.00 - 3.49             No
# 8/7/2020 12:05                     Year 1        3.00 - 3.49             No
# 8/7/2020 12:06                     year 3        3.00 - 3.49            Yes
# 8/7/2020 12:13                     year 4        3.00 - 3.49             No
# ...

# %%
df.tail(5)
# Out:
#                     Choose your gender   Age What is your course?  \
# Timestamp
# 13/07/2020 19:56:49             Female  21.0                  BCS
# 13/07/2020 21:21:42               Male  18.0          Engineering
# 13/07/2020 21:22:56             Female  19.0             Nursing
# 13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#                     Your current year of Study What is your CGPA?  \
# Timestamp
# 13/07/2020 19:56:49                     year 1        3.50 - 4.00
# 13/07/2020 21:21:42                     Year 2        3.00 - 3.49
# 13/07/2020 21:22:56                     Year 3        3.50 - 4.00
# 13/07/2020 21:23:57                     year 4        3.50 - 4.00
# 18/07/2020 20:16:21                     Year 2        3.00 - 3.49
#
#                     Marital status Do you have Depression?  \
# Timestamp
# 13/07/2020 19:56:49             No                      No
# ...

# %%
df.shape
# Out:
# (101, 10)

# %% [markdown]
# #### this tells you how many rows and columns there are.

# %%
list(df)
# Out:
# ['Choose your gender',
#  'Age',
#  'What is your course?',
#  'Your current year of Study',
#  'What is your CGPA?',
#  'Marital status',
#  'Do you have Depression?',
#  'Do you have Anxiety?',
#  'Do you have Panic attack?',
#  'Did you seek any specialist for a treatment?']

# %% [markdown]
# #### seeing that some of the columns are in longer named strings I wanted to simplify them.

# %%
df.rename(columns= {'Choose your gender':'Gender',
                               'What is your course?':'Course',
                               'Your current year of Study':'num_of_years',
                               'What is your CGPA?':'GPA',
                               'Marital status':'Married',
                               'Do you have Depression?':'Depression',
                               'Do you have Anxiety?':'Anxiety',
                               'Do you have Panic attack?':'Panic_attacks',
                               'Did you seek any specialist for a treatment?':'Treated'},
                     inplace= True)

# %% [markdown]
# #### this renames some of the columns that had longer names to simplified versions.

# %%
list(df)
# Out:
# ['Gender',
#  'Age',
#  'Course',
#  'num_of_years',
#  'GPA',
#  'Married',
#  'Depression',
#  'Anxiety',
#  'Panic_attacks',
#  'Treated']

# %%
df.duplicated()
# Out:
# Timestamp
# 8/7/2020 12:02         False
# 8/7/2020 12:04         False
# 8/7/2020 12:05         False
# 8/7/2020 12:06         False
# 8/7/2020 12:13         False
#                        ...
# 13/07/2020 19:56:49    False
# 13/07/2020 21:21:42    False
# 13/07/2020 21:22:56    False
# 13/07/2020 21:23:57    False
# 18/07/2020 20:16:21    False
# Length: 101, dtype: bool

# %% [markdown]
# #### checking for duplicated values, shows a boolean indicating there are none to be dropped.

# %%
df.isnull()
# Out:
#                      Gender    Age  Course  num_of_years    GPA  Married  \
# Timestamp
# 8/7/2020 12:02        False  False   False         False  False    False
# 8/7/2020 12:04        False  False   False         False  False    False
# 8/7/2020 12:05        False  False   False         False  False    False
# 8/7/2020 12:06        False  False   False         False  False    False
# 8/7/2020 12:13        False  False   False         False  False    False
# ...                     ...    ...     ...           ...    ...      ...
# 13/07/2020 19:56:49   False  False   False         False  False    False
# 13/07/2020 21:21:42   False  False   False         False  False    False
# 13/07/2020 21:22:56   False  False   False         False  False    False
# 13/07/2020 21:23:57   False  False   False         False  False    False
# 18/07/2020 20:16:21   False  False   False         False  False    False
#
#                      Depression  Anxiety  Panic_attacks  Treated
# Timestamp
# ...

# %% [markdown]
# #### checks for null values to be dropped, again there are none.

# %%
df.dtypes
# Out:
# Gender            object
# Age              float64
# Course            object
# num_of_years      object
# GPA               object
# Married           object
# Depression        object
# Anxiety           object
# Panic_attacks     object
# Treated           object
# dtype: object

# %% [markdown]
# #### checks the datatypes of all values within the dataset.

# %%
def HasStress():
    return(
    df[(df['Depression'] == 'Yes') 
                  & (df['Anxiety'] == 'Yes') 
                  & (df['Panic_attacks'] == 'Yes')])

# %%
HasStress()
# Out:
#                      Gender   Age          Course num_of_years          GPA  \
# Timestamp
# 8/7/2020 12:05         Male  19.0             BIT       Year 1  3.00 - 3.49
# 8/7/2020 12:52       Female  24.0             ENM       year 4  3.00 - 3.49
# 8/7/2020 13:07       Female  18.0  Marine science       year 2  3.50 - 4.00
# 8/7/2020 13:17       Female  23.0             BCS       Year 3  3.50 - 4.00
# 8/7/2020 13:58       Female  24.0             BIT       Year 3  3.50 - 4.00
# 8/7/2020 14:41       Female  19.0             BIT       year 1  3.00 - 3.49
# 8/7/2020 14:45       Female  19.0             BIT       year 1  2.50 - 2.99
# 8/7/2020 15:48       Female  20.0             koe       year 3  3.00 - 3.49
# 13/07/2020 10:11:26  Female  24.0  Communication        Year 2  3.50 - 4.00
# 13/07/2020 11:46:13  Female  18.0      psychology       year 1  3.50 - 4.00
#
#                     Married Depression Anxiety Panic_attacks Treated
# Timestamp
# ...

# %% [markdown]
# created a function that simplifies using the 3 quetions of stress repeatedly.

# %% [markdown]
# ## Question 1: What age has the highest of Depression, Anxiety, and Panic Attacks combined?

# %%
StressAge= HasStress()[['Age']].mode()

# %%
StressAge
# Out:
#     Age
# 0  19.0
# 1  24.0

# %%
plt.hist(depression)
plt.show()

# %%
depression= df['Depression']
depression
# Out:
# Timestamp
# 8/7/2020 12:02          No
# 8/7/2020 12:04         Yes
# 8/7/2020 12:05         Yes
# 8/7/2020 12:06          No
# 8/7/2020 12:13          No
#                       ...
# 13/07/2020 19:56:49    Yes
# 13/07/2020 21:21:42    Yes
# 13/07/2020 21:22:56     No
# 13/07/2020 21:23:57     No
# 18/07/2020 20:16:21     No
# Name: Anxiety, Length: 101, dtype: object

# %% [markdown]
# #### in this code I found the most common ages for depression, anxiety and panic attacks. Then after that list was made, using the mode() command found the 2 top ages which were 19 and 24.

# %%
HasStress()[['Gender']]
# Out:
#                      Gender
# Timestamp
# 8/7/2020 12:05         Male
# 8/7/2020 12:52       Female
# 8/7/2020 13:07       Female
# 8/7/2020 13:17       Female
# 8/7/2020 13:58       Female
# 8/7/2020 14:41       Female
# 8/7/2020 14:45       Female
# 8/7/2020 15:48       Female
# 13/07/2020 10:11:26  Female
# 13/07/2020 11:46:13  Female

# %% [markdown]
# ## Question 2: How many Students with all three diagnosis have received medical treatment. Also, how many students with fewer diagnosis of the three have received treatment?

# %%
HasStress()[['Treated']]
# Out:
#                     Treated
# Timestamp
# 8/7/2020 12:05           No
# 8/7/2020 12:52           No
# 8/7/2020 13:07           No
# 8/7/2020 13:17           No
# 8/7/2020 13:58          Yes
# 8/7/2020 14:41           No
# 8/7/2020 14:45           No
# 8/7/2020 15:48           No
# 13/07/2020 10:11:26      No
# 13/07/2020 11:46:13      No

# %%
df[df['Treated']== 'Yes']
# Out:
#                      Gender   Age       Course num_of_years          GPA  \
# Timestamp
# 8/7/2020 13:58       Female  24.0          BIT       Year 3  3.50 - 4.00
# 8/7/2020 14:31         Male  18.0          BCS       Year 2  3.50 - 4.00
# 8/7/2020 14:56       Female  24.0  Engineering       Year 2  2.50 - 2.99
# 8/7/2020 15:27       Female  23.0          ALA       year 1  2.50 - 2.99
# 8/7/2020 15:57       Female  19.0          BCS       year 1  3.50 - 4.00
# 13/07/2020 10:33:47  Female  18.0   psychology       year 1  3.50 - 4.00
#
#                     Married Depression Anxiety Panic_attacks Treated
# Timestamp
# 8/7/2020 13:58          Yes        Yes     Yes           Yes     Yes
# 8/7/2020 14:31          Yes        Yes     Yes            No     Yes
# 8/7/2020 14:56          Yes        Yes      No           Yes     Yes
# 8/7/2020 15:27          Yes        Yes      No           Yes     Yes
# 8/7/2020 15:57           No        Yes      No           Yes     Yes
# ...

# %% [markdown]
# for this code I wanted to compare the difference between the students with all three forms of stress seeking medical treatment and with just one of the three seeking treatment.
